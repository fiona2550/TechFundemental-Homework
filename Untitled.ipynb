# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
dfs = pd.read_excel('2017 Matriculant Satisfaction Survey_June 4, 2018_10.54_Edited.xlsx', keep_default_na= False)

# %%
dfs1 = pd.read_excel('2017 Matriculant Satisfaction Survey_June 4, 2018_10.54_Edited2.xlsx')

# %%
dfs[['D4_6_TEXT']].head()
# Out:
#          D4_6_TEXT
# 0
# 1
# 2
# 3  Caucasian/Asian
# 4

# %%
dfs[['OTD1']].head()
# Out:
#      OTD1
# 0  #NULL!
# 1  #NULL!
# 2  #NULL!
# 3  #NULL!
# 4  #NULL!

# %%
dfs = dfs.fillna('#NULL!')

# %%
dfs.head()
# Out:
#             StartDate             EndDate      Status        IPAddress  \
# 0 2018-05-08 10:32:15 2018-05-08 10:51:19  IP Address     170.212.0.96
# 1 2018-05-08 06:51:04 2018-05-08 06:59:46  IP Address   147.140.233.17
# 2 2018-05-10 16:25:40 2018-05-10 16:36:37  IP Address  147.140.127.133
# 3 2018-05-14 14:54:33 2018-05-14 14:58:26  IP Address      73.13.8.221
# 4 2018-05-11 17:18:44 2018-05-11 17:24:38  IP Address    73.160.48.211
#
#    Progress  Duration__in_seconds_  Finished        RecordedDate  \
# 0       100                   1143      True 2018-05-08 10:51:19
# 1       100                    522      True 2018-05-08 06:59:47
# 2       100                    657      True 2018-05-10 16:36:37
# 3       100                    233      True 2018-05-14 14:58:27
# 4       100                    353      True 2018-05-11 17:24:38
#
#           ResponseId RecipientLastName      ...      JCHP2_4 JCHP3 OTD1 OTD2  \
# ...

# %%
dfs1.replace('TEMP','#NULL!')
# Out:
#               StartDate             EndDate      Status        IPAddress  \
# 0   2018-05-08 10:32:15 2018-05-08 10:51:19  IP Address     170.212.0.96
# 1   2018-05-08 06:51:04 2018-05-08 06:59:46  IP Address   147.140.233.17
# 2   2018-05-10 16:25:40 2018-05-10 16:36:37  IP Address  147.140.127.133
# 3   2018-05-14 14:54:33 2018-05-14 14:58:26  IP Address      73.13.8.221
# 4   2018-05-11 17:18:44 2018-05-11 17:24:38  IP Address    73.160.48.211
# 5   2018-05-14 17:12:12 2018-05-14 17:15:23  IP Address   107.77.195.202
# 6   2018-05-14 13:10:24 2018-05-14 13:15:34  IP Address   107.77.195.157
# 7   2018-04-27 17:36:29 2018-04-27 17:39:52  IP Address      68.81.70.45
# 8   2018-05-16 08:29:35 2018-05-16 08:34:41  IP Address   147.140.233.30
# 9   2018-05-11 14:12:23 2018-05-11 14:15:20  IP Address    73.112.80.245
# 10  2018-05-24 22:17:52 2018-05-24 22:22:23  IP Address    50.245.138.93
# 11  2018-05-06 16:12:59 2018-05-06 16:19:13  IP Address     107.51.6.104
# ...

# %%
dfs = dfs['CL6']

# %%
dfs.tail()
# Out:
# 357
# 358    Would appreciate if the library was cleaned mo...
# 359
# 360                                                  N/A
# 361
# Name: CL6, dtype: object
